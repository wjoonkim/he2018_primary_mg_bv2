# %%
import pandas as pd

metadata = pd.read_csv('SraRunTable_Microglia_shaking_BV2.csv')
metadata = metadata[['Run', 'Sample Name']]
metadata.columns = ['run_accession', 'sample_name']
display(metadata)
# Out:
#   run_accession                     sample_name
# 0    SRR6047143  Microglia_shaking_PLL_culture1
# 1    SRR6047144  Microglia_shaking_PLL_culture2
# 2    SRR6047153                           BV2-2
# 3    SRR6047154                           BV2-1
# 4    SRR6047165                           BV2-4
# 5    SRR6047166                           BV2-3
# 6    SRR6047173  Microglia_shaking_PLL_culture4
# 7    SRR6047174  Microglia_shaking_PLL_culture3

# %%
metadata.to_csv('SraRunTable_MgShaking_BV2_Run_Sample_Name.csv', index=False)
